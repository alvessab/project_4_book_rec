# %%
import pandas as pd
import numpy as np

# keyword extraction and clean up
import nltk
from rake_nltk import Rake
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
import re


#Text Blob for sentiment analysis
from textblob import TextBlob


#tf-idf model
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer


from sklearn.metrics.pairwise import linear_kernel


import string
import random
from PIL import Image
import requests
from io import BytesIO

from langdetect import detect

# %%
df = pd.read_csv("../data/goodreads_final_seven.csv")
df.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/987587.The...
# 1     https://www.goodreads.com/book/show/73931.Hood
# 2  https://www.goodreads.com/book/show/10065.Ways...
# 3  https://www.goodreads.com/book/show/26114523-t...
# 4  https://www.goodreads.com/book/show/7736182-th...
#
#                            bookTitle  \
# 0                  The Crippled Lamb
# 1                               Hood
# 2     Wayside School Is Falling Down
# 3  The Summer that Melted Everything
# 4                      The Lost Hero
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                             bookDesc  bookRating  ratingCount  \
# 0  Because Joshua the Lamb was different, he ofte...        4.46         6670
# 1  Robin HoodThe Legend Begins AnewFor centuries,...        3.88        13570
# 2  Louis yard teacher starts off 30 tales of unus...        4.15        58464
# 3  Fielding Bliss has never forgotten the summer ...        3.97         7209
# 4  JASON HAS A PROBLEM. He doesn’t remember anyth...        4.32       670659
#
#    reviewCount      Genre  pageCount              Author lang
# 0          224      Other         32          Max Lucado   en
# 1         1389    Fantasy        490  Stephen R. Lawhead   en
# 2         1059  Childrens        152        Louis Sachar   en
# 3         1581    Fiction        310  Tiffany   McDaniel   en
# 4        23261    Fantasy        553        Rick Riordan   en

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   url          5000 non-null   object
#  1   bookTitle    5000 non-null   object
#  2   bookImage    5000 non-null   object
#  3   bookDesc     5000 non-null   object
#  4   bookRating   5000 non-null   float64
#  5   ratingCount  5000 non-null   int64
#  6   reviewCount  5000 non-null   int64
#  7   Genre        5000 non-null   object
#  8   pageCount    5000 non-null   int64
#  9   Author       5000 non-null   object
#  10  lang         5000 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 429.8+ KB

# %% [markdown]
# ### key words processing

# %%
#data pre-processing to remove stop words, punctuation, white space, and convert all words to lower case from book Description
df_new = df.copy()
key_words = []
title_key_words = []

r = Rake()

for index, row in df_new.iterrows():
    r.extract_keywords_from_text(row['bookDesc'])
    key_words_dict_scores = r.get_word_degrees()
    keywords = list(key_words_dict_scores.keys())
    
    
    key_words.append(keywords)

    r.extract_keywords_from_text(row['bookTitle'])
    key_words_dict_scores = r.get_word_degrees()
    title_keywords = list(key_words_dict_scores.keys())
    
    title_key_words.append(title_keywords)
    
df_new["key_words"] = key_words
df_new["title_key_words"] = title_key_words

df_new.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/987587.The...
# 1     https://www.goodreads.com/book/show/73931.Hood
# 2  https://www.goodreads.com/book/show/10065.Ways...
# 3  https://www.goodreads.com/book/show/26114523-t...
# 4  https://www.goodreads.com/book/show/7736182-th...
#
#                            bookTitle  \
# 0                  The Crippled Lamb
# 1                               Hood
# 2     Wayside School Is Falling Down
# 3  The Summer that Melted Everything
# 4                      The Lost Hero
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                             bookDesc  bookRating  ratingCount  \
# 0  Because Joshua the Lamb was different, he ofte...        4.46         6670
# 1  Robin HoodThe Legend Begins AnewFor centuries,...        3.88        13570
# 2  Louis yard teacher starts off 30 tales of unus...        4.15        58464
# 3  Fielding Bliss has never forgotten the summer ...        3.97         7209
# 4  JASON HAS A PROBLEM. He doesn’t remember anyth...        4.32       670659
#
#    reviewCount      Genre  pageCount              Author lang  \
# 0          224      Other         32          Max Lucado   en
# 1         1389    Fantasy        490  Stephen R. Lawhead   en
# 2         1059  Childrens        152        Louis Sachar   en
# 3         1581    Fiction        310  Tiffany   McDaniel   en
# 4        23261    Fantasy        553        Rick Riordan   en
#
#                                            key_words  \
# 0  [joshua, lamb, different, often, felt, left, l...
# 1  [robin, hoodthe, legend, begins, anewfor, cent...
# 2  [louis, yard, teacher, starts, 30, tales, unus...
# 3  [fielding, bliss, never, forgotten, summer, 19...
# 4  [jason, problem, ’, remember, anything, waking...
#
#                 title_key_words
# 0              [crippled, lamb]
# 1                        [hood]
# 2    [wayside, school, falling]
# 3  [summer, melted, everything]
# 4                  [lost, hero]

# %%
df_new2 = df_new.copy()

# %%
# clean up keywords: drop symbols and numbers, as well as find root words

lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer() 

def preprocess(sentence):
    sentence=str(sentence)
    sentence = sentence.lower()
    sentence=sentence.replace('{html}',"") 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url=re.sub(r'http\S+', '',cleantext)
    rem_num = re.sub('[0-9]+', '', rem_url)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)  
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]
    stem_words=[stemmer.stem(w) for w in filtered_words]
    lemma_words=[lemmatizer.lemmatize(w) for w in stem_words]
    return " ".join(filtered_words)


df_new2['clean_keywords']=df_new2['key_words'].map(lambda s:preprocess(s))

# %%
df_new2.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/987587.The...
# 1     https://www.goodreads.com/book/show/73931.Hood
# 2  https://www.goodreads.com/book/show/10065.Ways...
# 3  https://www.goodreads.com/book/show/26114523-t...
# 4  https://www.goodreads.com/book/show/7736182-th...
#
#                            bookTitle  \
# 0                  The Crippled Lamb
# 1                               Hood
# 2     Wayside School Is Falling Down
# 3  The Summer that Melted Everything
# 4                      The Lost Hero
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                             bookDesc  bookRating  ratingCount  \
# 0  Because Joshua the Lamb was different, he ofte...        4.46         6670
# 1  Robin HoodThe Legend Begins AnewFor centuries,...        3.88        13570
# 2  Louis yard teacher starts off 30 tales of unus...        4.15        58464
# 3  Fielding Bliss has never forgotten the summer ...        3.97         7209
# 4  JASON HAS A PROBLEM. He doesn’t remember anyth...        4.32       670659
#
#    reviewCount      Genre  pageCount              Author lang  \
# 0          224      Other         32          Max Lucado   en
# 1         1389    Fantasy        490  Stephen R. Lawhead   en
# 2         1059  Childrens        152        Louis Sachar   en
# 3         1581    Fiction        310  Tiffany   McDaniel   en
# 4        23261    Fantasy        553        Rick Riordan   en
#
#                                            key_words  \
# 0  [joshua, lamb, different, often, felt, left, l...
# 1  [robin, hoodthe, legend, begins, anewfor, cent...
# 2  [louis, yard, teacher, starts, 30, tales, unus...
# 3  [fielding, bliss, never, forgotten, summer, 19...
# 4  [jason, problem, ’, remember, anything, waking...
#
#                 title_key_words  \
# 0              [crippled, lamb]
# 1                        [hood]
# 2    [wayside, school, falling]
# 3  [summer, melted, everything]
# 4                  [lost, hero]
#
#                                       clean_keywords
# 0  joshua lamb different often felt left like win...
# 1  robin hoodthe legend begins anewfor centuries ...
# 2  louis yard teacher starts tales unusual studen...
# 3  fielding bliss never forgotten summer year hea...
# 4  jason problem remember anything waking bus ful...

# %%
df_new2 = df_new2.drop(columns=['key_words'])

# %%
df_new2.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/987587.The...
# 1     https://www.goodreads.com/book/show/73931.Hood
# 2  https://www.goodreads.com/book/show/10065.Ways...
# 3  https://www.goodreads.com/book/show/26114523-t...
# 4  https://www.goodreads.com/book/show/7736182-th...
#
#                            bookTitle  \
# 0                  The Crippled Lamb
# 1                               Hood
# 2     Wayside School Is Falling Down
# 3  The Summer that Melted Everything
# 4                      The Lost Hero
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                             bookDesc  bookRating  ratingCount  \
# 0  Because Joshua the Lamb was different, he ofte...        4.46         6670
# 1  Robin HoodThe Legend Begins AnewFor centuries,...        3.88        13570
# 2  Louis yard teacher starts off 30 tales of unus...        4.15        58464
# 3  Fielding Bliss has never forgotten the summer ...        3.97         7209
# 4  JASON HAS A PROBLEM. He doesn’t remember anyth...        4.32       670659
#
#    reviewCount      Genre  pageCount              Author lang  \
# 0          224      Other         32          Max Lucado   en
# 1         1389    Fantasy        490  Stephen R. Lawhead   en
# 2         1059  Childrens        152        Louis Sachar   en
# 3         1581    Fiction        310  Tiffany   McDaniel   en
# 4        23261    Fantasy        553        Rick Riordan   en
#
#                 title_key_words  \
# 0              [crippled, lamb]
# 1                        [hood]
# 2    [wayside, school, falling]
# 3  [summer, melted, everything]
# 4                  [lost, hero]
#
#                                       clean_keywords
# 0  joshua lamb different often felt left like win...
# 1  robin hoodthe legend begins anewfor centuries ...
# 2  louis yard teacher starts tales unusual studen...
# 3  fielding bliss never forgotten summer year hea...
# 4  jason problem remember anything waking bus ful...

# %% [markdown]
# ### Sentiment Analysis with Text Blob

# %%
# test Text Blob program
# Preparing an input sentence
sentence = '''The platform provides universal access to the world's best education, partnering with top universities and organizations to offer courses online.'''

# Creating a textblob object and assigning the sentiment property
analysis = TextBlob(sentence).sentiment
print(analysis)
print(analysis[0])
print(analysis[1])
# Out:
# Sentiment(polarity=0.5, subjectivity=0.26666666666666666)
# 0.5
# 0.26666666666666666

# %%
df_sub = df_new2.copy()

# %%
# run text blob in a loop

polarities = []
subjectivities = []

for index, row in df_sub.iterrows():
    sentence = row['bookDesc']
    analysis = TextBlob(sentence).sentiment
    polarity = analysis[0]
    subjectivity = analysis[1]

    # populate lists
    polarities.append(polarity)
    subjectivities.append(subjectivity)


df_sub['sentiment_polarity'] = polarities
df_sub['sentiment_subjectivity']= subjectivities

df_sub.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/987587.The...
# 1     https://www.goodreads.com/book/show/73931.Hood
# 2  https://www.goodreads.com/book/show/10065.Ways...
# 3  https://www.goodreads.com/book/show/26114523-t...
# 4  https://www.goodreads.com/book/show/7736182-th...
#
#                            bookTitle  \
# 0                  The Crippled Lamb
# 1                               Hood
# 2     Wayside School Is Falling Down
# 3  The Summer that Melted Everything
# 4                      The Lost Hero
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                             bookDesc  bookRating  ratingCount  \
# 0  Because Joshua the Lamb was different, he ofte...        4.46         6670
# 1  Robin HoodThe Legend Begins AnewFor centuries,...        3.88        13570
# 2  Louis yard teacher starts off 30 tales of unus...        4.15        58464
# 3  Fielding Bliss has never forgotten the summer ...        3.97         7209
# 4  JASON HAS A PROBLEM. He doesn’t remember anyth...        4.32       670659
#
#    reviewCount      Genre  pageCount              Author lang  \
# 0          224      Other         32          Max Lucado   en
# 1         1389    Fantasy        490  Stephen R. Lawhead   en
# 2         1059  Childrens        152        Louis Sachar   en
# 3         1581    Fiction        310  Tiffany   McDaniel   en
# 4        23261    Fantasy        553        Rick Riordan   en
#
#                 title_key_words  \
# 0              [crippled, lamb]
# 1                        [hood]
# 2    [wayside, school, falling]
# 3  [summer, melted, everything]
# 4                  [lost, hero]
#
#                                       clean_keywords  sentiment_polarity  \
# 0  joshua lamb different often felt left like win...            0.067857
# 1  robin hoodthe legend begins anewfor centuries ...            0.142803
# 2  louis yard teacher starts tales unusual studen...            0.293750
# 3  fielding bliss never forgotten summer year hea...            0.028214
# 4  jason problem remember anything waking bus ful...            0.016883
#
#    sentiment_subjectivity
# 0                0.485714
# 1                0.427121
# 2                0.462500
# 3                0.514821
# 4                0.419610

# %%
#save dataframe to csv
df_sub.to_csv("../data/goodreads_sentiment.csv", index=False)

# %% [markdown]
# ### TF-IDF feature columns

# %%
#df_tf = df_sub.copy()

# %%
#from sklearn.feature_extraction.text import TfidfVectorizer


#vect = TfidfVectorizer()
#tfidf_matrix = vect.fit_transform(df_tf['clean_keywords'])
#df_data = pd.DataFrame(tfidf_matrix.toarray(), columns = vect.get_feature_names())
#df_data.head()

# %%
#df_data.max()

# %%
#df_data.info()

# %%
#save dataframe to csv
#df_data.to_csv("../data/goodreads_tfidf_data.csv", index=False)

#file too large for github: 1.65 GB

# %%
#df_data.to_parquet("../data/goodreads_tfidf_data.parquet", index=False, compression=None, engine="fastparquet")

# %%
#df_knn =  pd.concat([df_tf, df_data], axis=0)
#df_knn.info()

# %%
#df_knn.head()

# %%
#save dataframe to csv
#df_knn.to_csv("../data/goodreads_final_knn.csv", index=False)
#file 2.06GB and too big for github

# %% [markdown]
# ### Bag of Words DF

# %%
df_bog = df_sub.copy()

# %%
#make columns lower case

df_bog['genre_bag'] = df_bog['Genre'].str.lower()

#make columns one string
df_bog['genre_bag'] = df_bog['genre_bag'].str.replace(" ","")

#add brackets for processing in next step
df_bog['genre_bag'] = df_bog['genre_bag'].apply(lambda x: x.split(','))

df_bog.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/987587.The...
# 1     https://www.goodreads.com/book/show/73931.Hood
# 2  https://www.goodreads.com/book/show/10065.Ways...
# 3  https://www.goodreads.com/book/show/26114523-t...
# 4  https://www.goodreads.com/book/show/7736182-th...
#
#                            bookTitle  \
# 0                  The Crippled Lamb
# 1                               Hood
# 2     Wayside School Is Falling Down
# 3  The Summer that Melted Everything
# 4                      The Lost Hero
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                             bookDesc  bookRating  ratingCount  \
# 0  Because Joshua the Lamb was different, he ofte...        4.46         6670
# 1  Robin HoodThe Legend Begins AnewFor centuries,...        3.88        13570
# 2  Louis yard teacher starts off 30 tales of unus...        4.15        58464
# 3  Fielding Bliss has never forgotten the summer ...        3.97         7209
# 4  JASON HAS A PROBLEM. He doesn’t remember anyth...        4.32       670659
#
#    reviewCount      Genre  pageCount              Author lang  \
# 0          224      Other         32          Max Lucado   en
# 1         1389    Fantasy        490  Stephen R. Lawhead   en
# 2         1059  Childrens        152        Louis Sachar   en
# 3         1581    Fiction        310  Tiffany   McDaniel   en
# 4        23261    Fantasy        553        Rick Riordan   en
#
#                 title_key_words  \
# 0              [crippled, lamb]
# 1                        [hood]
# 2    [wayside, school, falling]
# 3  [summer, melted, everything]
# 4                  [lost, hero]
#
#                                       clean_keywords  sentiment_polarity  \
# 0  joshua lamb different often felt left like win...            0.067857
# 1  robin hoodthe legend begins anewfor centuries ...            0.142803
# 2  louis yard teacher starts tales unusual studen...            0.293750
# 3  fielding bliss never forgotten summer year hea...            0.028214
# 4  jason problem remember anything waking bus ful...            0.016883
#
#    sentiment_subjectivity    genre_bag
# 0                0.485714      [other]
# 1                0.427121    [fantasy]
# 2                0.462500  [childrens]
# 3                0.514821    [fiction]
# 4                0.419610    [fantasy]

# %%
df_bog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   url                     5000 non-null   object
#  1   bookTitle               5000 non-null   object
#  2   bookImage               5000 non-null   object
#  3   bookDesc                5000 non-null   object
#  4   bookRating              5000 non-null   float64
#  5   ratingCount             5000 non-null   int64
#  6   reviewCount             5000 non-null   int64
#  7   Genre                   5000 non-null   object
#  8   pageCount               5000 non-null   int64
#  9   Author                  5000 non-null   object
#  10  lang                    5000 non-null   object
#  11  title_key_words         5000 non-null   object
#  12  clean_keywords          5000 non-null   object
#  13  sentiment_polarity      5000 non-null   float64
#  14  sentiment_subjectivity  5000 non-null   float64
#  15  genre_bag               5000 non-null   object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 625.1+ KB

# %%
#make book description column a list of words
clean_keywords= []
for index, row in df_bog.iterrows():
    txt = row['clean_keywords']
    clean_keyword_list =  list(txt.split())
    
    clean_keywords.append(clean_keyword_list)
    
df_bog['clean_keywords'] = clean_keywords
df_bog.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/987587.The...
# 1     https://www.goodreads.com/book/show/73931.Hood
# 2  https://www.goodreads.com/book/show/10065.Ways...
# 3  https://www.goodreads.com/book/show/26114523-t...
# 4  https://www.goodreads.com/book/show/7736182-th...
#
#                            bookTitle  \
# 0                  The Crippled Lamb
# 1                               Hood
# 2     Wayside School Is Falling Down
# 3  The Summer that Melted Everything
# 4                      The Lost Hero
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                             bookDesc  bookRating  ratingCount  \
# 0  Because Joshua the Lamb was different, he ofte...        4.46         6670
# 1  Robin HoodThe Legend Begins AnewFor centuries,...        3.88        13570
# 2  Louis yard teacher starts off 30 tales of unus...        4.15        58464
# 3  Fielding Bliss has never forgotten the summer ...        3.97         7209
# 4  JASON HAS A PROBLEM. He doesn’t remember anyth...        4.32       670659
#
#    reviewCount      Genre  pageCount              Author lang  \
# 0          224      Other         32          Max Lucado   en
# 1         1389    Fantasy        490  Stephen R. Lawhead   en
# 2         1059  Childrens        152        Louis Sachar   en
# 3         1581    Fiction        310  Tiffany   McDaniel   en
# 4        23261    Fantasy        553        Rick Riordan   en
#
#                 title_key_words  \
# 0              [crippled, lamb]
# 1                        [hood]
# 2    [wayside, school, falling]
# 3  [summer, melted, everything]
# 4                  [lost, hero]
#
#                                       clean_keywords  sentiment_polarity  \
# 0  [joshua, lamb, different, often, felt, left, l...            0.067857
# 1  [robin, hoodthe, legend, begins, anewfor, cent...            0.142803
# 2  [louis, yard, teacher, starts, tales, unusual,...            0.293750
# 3  [fielding, bliss, never, forgotten, summer, ye...            0.028214
# 4  [jason, problem, remember, anything, waking, b...            0.016883
#
#    sentiment_subjectivity    genre_bag
# 0                0.485714      [other]
# 1                0.427121    [fantasy]
# 2                0.462500  [childrens]
# 3                0.514821    [fiction]
# 4                0.419610    [fantasy]

# %%
#join columns to make bag
#create a bag of words columns with processed columns
df_bog2 = df_bog.copy()

df_bog2['bag_of_words'] = ''

columns = ['genre_bag', 'title_key_words', 'clean_keywords']

bagWords = []

for index, row in df_bog2.iterrows():
    words = ''
    for col in columns:
        words += ' '.join(row[col]) + ' '
    bagWords.append(words) 
    
df_bog2['bag_of_words'] = bagWords
df_bog2.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/987587.The...
# 1     https://www.goodreads.com/book/show/73931.Hood
# 2  https://www.goodreads.com/book/show/10065.Ways...
# 3  https://www.goodreads.com/book/show/26114523-t...
# 4  https://www.goodreads.com/book/show/7736182-th...
#
#                            bookTitle  \
# 0                  The Crippled Lamb
# 1                               Hood
# 2     Wayside School Is Falling Down
# 3  The Summer that Melted Everything
# 4                      The Lost Hero
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                             bookDesc  bookRating  ratingCount  \
# 0  Because Joshua the Lamb was different, he ofte...        4.46         6670
# 1  Robin HoodThe Legend Begins AnewFor centuries,...        3.88        13570
# 2  Louis yard teacher starts off 30 tales of unus...        4.15        58464
# 3  Fielding Bliss has never forgotten the summer ...        3.97         7209
# 4  JASON HAS A PROBLEM. He doesn’t remember anyth...        4.32       670659
#
#    reviewCount      Genre  pageCount              Author lang  \
# 0          224      Other         32          Max Lucado   en
# 1         1389    Fantasy        490  Stephen R. Lawhead   en
# 2         1059  Childrens        152        Louis Sachar   en
# 3         1581    Fiction        310  Tiffany   McDaniel   en
# 4        23261    Fantasy        553        Rick Riordan   en
#
#                 title_key_words  \
# 0              [crippled, lamb]
# 1                        [hood]
# 2    [wayside, school, falling]
# 3  [summer, melted, everything]
# 4                  [lost, hero]
#
#                                       clean_keywords  sentiment_polarity  \
# 0  [joshua, lamb, different, often, felt, left, l...            0.067857
# 1  [robin, hoodthe, legend, begins, anewfor, cent...            0.142803
# 2  [louis, yard, teacher, starts, tales, unusual,...            0.293750
# 3  [fielding, bliss, never, forgotten, summer, ye...            0.028214
# 4  [jason, problem, remember, anything, waking, b...            0.016883
#
#    sentiment_subjectivity    genre_bag  \
# 0                0.485714      [other]
# 1                0.427121    [fantasy]
# 2                0.462500  [childrens]
# 3                0.514821    [fiction]
# 4                0.419610    [fantasy]
#
#                                         bag_of_words
# 0  other crippled lamb joshua lamb different ofte...
# 1  fantasy hood robin hoodthe legend begins anewf...
# 2  childrens wayside school falling louis yard te...
# 3  fiction summer melted everything fielding blis...
# 4  fantasy lost hero jason problem remember anyth...

# %%
#save dataframe to csv
df_bog2.to_csv("../data/goodreads_final_bagowords.csv", index=False)
