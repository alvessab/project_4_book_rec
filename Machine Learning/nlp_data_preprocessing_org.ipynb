# %%
import pandas as pd
import numpy as np

# Importing TextBlob
from textblob import TextBlob

#get key words
import nltk
from rake_nltk import Rake
from nltk.corpus import stopwords

from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

import re
import string
import random

from PIL import Image
import requests
from io import BytesIO

# %%
df = pd.read_csv("../data/goodreads_final_cleaned")
df.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/2767052-th...
# 1  https://www.goodreads.com/book/show/2.Harry_Po...
# 2  https://www.goodreads.com/book/show/2657.To_Ki...
# 3  https://www.goodreads.com/book/show/1885.Pride...
# 4  https://www.goodreads.com/book/show/41865.Twil...
#
#                                    bookTitle  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
# ...

# %% [markdown]
# ### Sentiment Analysis (Text Blob)

# %%
# test Text Blob program
# Preparing an input sentence
sentence = '''The platform provides universal access to the world's best education, partnering with top universities and organizations to offer courses online.'''

# Creating a textblob object and assigning the sentiment property
analysis = TextBlob(sentence).sentiment
print(analysis)
print(analysis[0])
print(analysis[1])
# Out:
# Sentiment(polarity=0.5, subjectivity=0.26666666666666666)
# 0.5
# 0.26666666666666666

# %%
df_sub= df.copy()

# %%
# run text blog in a loop

polarities = []
subjectivities = []


for index, row in df_sub.iterrows():
    sentence = row['bookDesc']
    analysis = TextBlob(sentence).sentiment
    polarity = analysis[0]
    subjectivity = analysis[1]

    # populate lists
    polarities.append(row.polarity)
    subjectivities.append(row.subjectivity)


#df_sub['polarity'] = polarities
#df_sub['subjectivity']= subjectivities

#df_sub.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/93/69nrl93d0k36xslv9kn84gcc0000gn/T/ipykernel_59593/2016595260.py in <module>
#      12
#      13     # populate lists
# ---> 14     polarities.append(row.polarity)
#      15     subjectivities.append(row.subjectivity)
#      16
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'polarity'

# %%
# run text blog in a loop
df_sub= df.copy()
df_sub['polarity'] = ''
df_sub['subjectivity'] = ''


for index, row in df_sub.iterrows():
    sentence = row['bookDesc']
    analysis = TextBlob(sentence).sentiment
    row['polarity'] = analysis[0]
    row['subjectivity'] = analysis[1]


df_sub.head()
# Out:
#                                                                                url  \
# 0                     https://www.goodreads.com/book/show/2767052-the-hunger-games
# 1  https://www.goodreads.com/book/show/2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird
# 3                     https://www.goodreads.com/book/show/1885.Pride_and_Prejudice
# 4                               https://www.goodreads.com/book/show/41865.Twilight
#
#                                    bookTitle  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                                                                        bookImage  \
# ...

# %% [markdown]
# ### bookDesc keywords

# %%
df_new = df_sub.copy()
df_new.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/2767052-th...
# 1  https://www.goodreads.com/book/show/2.Harry_Po...
# 2  https://www.goodreads.com/book/show/2657.To_Ki...
# 3  https://www.goodreads.com/book/show/1885.Pride...
# 4  https://www.goodreads.com/book/show/41865.Twil...
#
#                                    bookTitle  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
# ...

# %%
#data pre-processing to remove stop words, punctuation, white space, and convert all words to lower case from book Description

df_new['Key_words'] = ''
df_new['bookTitle_key'] = ''
r = Rake()

for index, row in df_new.iterrows():
    r.extract_keywords_from_text(row['bookDesc'])
    key_words_dict_scores = r.get_word_degrees()
    row['Key_words'] = list(key_words_dict_scores.keys())

    r.extract_keywords_from_text(row['bookTitle'])
    key_words_dict_scores = r.get_word_degrees()
    row['bookTitle_key'] = list(key_words_dict_scores.keys())
    
    
df_new.head()
# Out:
#                                                  url  \
# 0  https://www.goodreads.com/book/show/2767052-th...
# 1  https://www.goodreads.com/book/show/2.Harry_Po...
# 2  https://www.goodreads.com/book/show/2657.To_Ki...
# 3  https://www.goodreads.com/book/show/1885.Pride...
# 4  https://www.goodreads.com/book/show/41865.Twil...
#
#                                    bookTitle  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                            bookImage  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
# ...

# %% [markdown]
# ### TF-IDF Feature Encoding

# %%
#save file

# %% [markdown]
# ### Bag of Words
